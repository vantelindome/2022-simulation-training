# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import numpy as np
import math

# %%
plt.rcParams["text.usetex"] =True 
fig = plt.figure()
ax = fig.add_subplot(111)

# plot from txt file
x, y = np.loadtxt('buffon.txt', unpack=True, usecols=[0,1])
plt.plot(x, y, label='measured pi')

# plot theoretical line
y1 = x*0 + math.pi
plt.plot(x, y1, color='r', label='Theoretical pi') 

plt.title("Calculate pi using Buffon's pin")
plt.xscale('log')
plt.xlabel('number of dropped pins')
plt.ylabel('measured Pi')

plt.legend()
plt.savefig('problem1-2.png')
plt.savefig('problem1-2.pdf')
plt.show()

# %%
plt.rcParams["text.usetex"] =True 
# fig = plt.figure()
# ax = fig.add_subplot(111)
fig, ax = plt.subplots()

# plot from txt file
x, y = np.loadtxt('buffon.txt', unpack=True, usecols=[0,2])
ax.plot(x, y, label='absolute error of pi')

# plot theoretical line
y1 = 3.0 / np.sqrt(x)
ax.plot(x, y1, color='r', label='$C/\sqrt{n}$') 

ax.set_title("Absolute error of calculated Pi")
ax.set_xscale('log')
ax.set_xlabel('number of dropped pins')
ax.set_yscale('log')
ax.set_ylabel('absolute error of Pi')

plt.legend()
plt.savefig('problem1-3.png')
plt.savefig('problem1-3.pdf')
plt.show()
